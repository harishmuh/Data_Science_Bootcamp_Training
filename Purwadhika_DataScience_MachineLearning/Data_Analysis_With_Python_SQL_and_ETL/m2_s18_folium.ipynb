# %% [markdown]
# # **Introduction to Folium**
#
# Kita akan belajar cara membuat peta untuk berbagai tujuan. Untuk melakukannya, kita akan berpisah dengan Matplotlib dan bekerja dengan pustaka visualisasi Python lainnya, yaitu **Folium**. Hal yang menarik tentang **Folium** adalah ia dikembangkan hanya untuk tujuan memvisualisasikan data geospasial.
#
# Meskipun pustaka lain tersedia untuk memvisualisasikan data geospasial, seperti **plotly**, pustaka tersebut mungkin memiliki batasan terkait berapa banyak panggilan API yang dapat dilakukan dalam jangka waktu yang ditentukan. Sedangkan **Folium** sepenuhnya gratis.
# ___

# %%
# pip install folium

# %%
# data manipulation
import numpy as np  
import pandas as pd 

# visualization
import folium

# %% [markdown]
# ## **1. What is Folium?**
#
#
# Folium adalah sebuah library Python yang powerful yang membantu Anda membuat berbagai jenis peta Leaflet. Fakta bahwa hasil dari Folium interaktif membuat library ini sangat berguna untuk membangun dashboard.
#
# Dari halaman dokumentasi resmi Folium:
#
# > Folium memanfaatkan kekuatan pengolahan data dari ekosistem Python dan kekuatan pemetaan dari pustaka Leaflet.js. Manipulasi data Anda di Python, kemudian visualisasikan pada peta Leaflet melalui Folium.
#
# > Folium memudahkan untuk memvisualisasikan data yang telah dimanipulasi di Python pada peta Leaflet interaktif. Ini memungkinkan pengikatan data ke peta untuk visualisasi choropleth serta melewati visualisasi Vincent/Vega sebagai penanda pada peta.
#
# > Pustaka ini memiliki sejumlah tilesets bawaan dari OpenStreetMap, Mapbox, Cartodb, dan mendukung tilesets kustom dengan kunci API Mapbox atau Cloudmade. Folium mendukung baik overlay GeoJSON maupun TopoJSON, serta pengikatan data ke overlay tersebut untuk membuat peta choropleth dengan skema warna color-brewer.

# %% [markdown]
# ## **2. Generating Maps**
#
#
# Membuat peta dunia sangat mudah di Folium. Kita hanya perlu membuat objek `Map` Folium, dan kemudian menampilkannya. Yang menarik dari peta Folium adalah bahwa mereka interaktif, sehingga kita dapat memperbesar tampilan ke area mana pun yang menarik meskipun pada tingkat zoom awal.

# %%
# define the world_map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c93395f720cde8182b8f6ccca28dfbd9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c93395f720cde8182b8f6ccca28dfbd9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c93395f720cde8182b8f6ccca28dfbd9 = L.map(
#                 &quot;map_c93395f720cde8182b8f6ccca28dfbd9&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_124c839a06e4bcd345fa575b173a154b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c93395f720cde8182b8f6ccca28dfbd9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Coba perbesar dan perkecil peta yang diberikan di atas.
#
# Kita dapat menyesuaikan definisi default peta dunia ini dengan menentukan pusat peta kita, dan tingkat zoom awal.
#
# Semua lokasi pada peta didefinisikan oleh nilai Latitude dan Longitude mereka masing-masing. Jadi kita dapat membuat peta dan menyertakan pusat nilai Latitude dan Longitude **[0, 0]**.
#
# Untuk pusat yang ditentukan, kita juga dapat menentukan tingkat zoom awal ke lokasi tersebut saat peta dirender. **Semakin tinggi tingkat zoom, semakin besar peta diperbesar ke pusatnya.**
#
# Mari kita membuat peta yang berpusat di sekitar Jakarta dan bermain dengan tingkat zoom untuk melihat bagaimana itu memengaruhi peta yang dirender.

# %%
# menampilkan peta jakarta yang berpusat di monas
lat_monas = -6.175392 
long_monas = 106.827153

jakarta_map = folium.Map([lat_monas, long_monas], zoom_start=12)
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ff3d150742a3e2adb9b35e0f64732de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ff3d150742a3e2adb9b35e0f64732de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4ff3d150742a3e2adb9b35e0f64732de = L.map(
#                 &quot;map_4ff3d150742a3e2adb9b35e0f64732de&quot;,
#                 {
#                     center: [-6.175392, 106.827153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed2f104b9c91966525199d1c12c9f731 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4ff3d150742a3e2adb9b35e0f64732de);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Seperti yang kita lihat, semakin tinggi tingkat zoom, semakin besar peta diperbesar ke bagian tengahnya.

# %% [markdown]
# ## **2. Map Style**
#
# Fitur keren lainnya dari **Folium** adalah kita dapat menghasilkan gaya peta yang berbeda.
#
# ### `Cartodb dark_matter Maps`
#
# Ini adalah peta hitam putih dengan kontras tinggi. Cocok untuk penggabungan data dan menjelajahi liku-liku sungai dan zona pesisir.
#
# Mari kita membuat peta Cartodb dark_matter Surabaya dengan tingkat zoom 12.

# %%
# membuat peta surabaya
surabaya_map = folium.Map([-7.290704510409528, 112.73623511924048], zoom_start=12, tiles='Cartodb dark_matter')
surabaya_map

# location: [latitude, longitude]
# zoom_start : ukuran awal dari tampilan
# tiles : style dari peta (by default open streen map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0756916e03d38da898ae2b8f9f8d6182 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0756916e03d38da898ae2b8f9f8d6182&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0756916e03d38da898ae2b8f9f8d6182 = L.map(
#                 &quot;map_0756916e03d38da898ae2b8f9f8d6182&quot;,
#                 {
#                     center: [-7.290704510409528, 112.73623511924048],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f02dfd7a84961ac067eb238b7ed6aea = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0756916e03d38da898ae2b8f9f8d6182);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### `Cartodb positron Maps`
#
# Peta CartoDB Positron didesain dengan estetika ringan dan minimalis. Mereka memiliki latar belakang putih atau berwarna terang dan menampilkan garis-garis sederhana dan bersih untuk elemen peta. Peta-peta ini dikenal dengan desainnya yang modern dan menarik secara visual.
#
# Mari kita membuat peta Cartodb Positron Bandung dengan tingkat zoom 12.

# %%
bandung_map = folium.Map([-6.921687677732648, 107.61605423823936], zoom_start=12, tiles='Cartodb positron')
bandung_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd53300bc73cfa4af6289e242637299b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd53300bc73cfa4af6289e242637299b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_dd53300bc73cfa4af6289e242637299b = L.map(
#                 &quot;map_dd53300bc73cfa4af6289e242637299b&quot;,
#                 {
#                     center: [-6.921687677732648, 107.61605423823936],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ec6293ff1fc3bb0a580e1528971178b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dd53300bc73cfa4af6289e242637299b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **3. Maps with Markers**
#
# Kita dapat menambahkan penanda pada suatu peta. Kita dapat menambahkan penanda ini ke peta kita dengan memanggil `folium.Marker()` dan menyimpan lokasi titik tersebut

# %%
jakarta_map = folium.Map([lat_monas, long_monas], zoom_start=12)

# membuat marker monas
monas_pin = folium.Marker(
    location=[-6.175173679016957, 106.827148217066],
    tooltip='Monumen Nasional',                                             # label ketika dihover
    popup='Monas merupakan monumen peringatan setinggi 132 meter',          # label ketika diklik
    icon=folium.Icon(
        icon='building',                                                    # ikon yang ditampilkan                                  
        prefix='fa',                                                        # prefix='fa' digunakan jika menggunakan icon dari fontawesome
        color='red'                                                         # warna
    )
)

# membuat marker bandara halim
halim_pin = folium.Marker(
    location=[-6.265071274791165, 106.88555279590285],
    tooltip='Bandara Halim',                                                # label ketika dihover
    popup='Bandar Udara sipil utama di Kota Jakarta',                       # label ketika diklik
    icon=folium.Icon(
        icon='plane',                                                       # ikon yang ditampilkan                                  
        prefix='fa',                                                        # prefix='fa' digunakan jika menggunakan icon dari fontawesome
        color='orange'                                                         # warna
    )
)

# membuat marker berupa lingkaran
pik_area = folium.CircleMarker(                                             # ketika dizoom, ukurannya tetap, tidak membesar atau mengecil. ukuran mempertahan pixel
    location=[-6.1089382715126055, 106.73995330939384], 
    tooltip='Pantai Indah Kapuk',
    popup='Area Rawan Bencana Banjir Rob',
    radius=100,                                                             # radius dalam satuan pixel
    color='red'
)

# membuat marker berupa lingkaran
ancol_area = folium.Circle(                                                 # ketika dizoom, akan membesar atau mengecil 
    location=[-6.117928361275429, 106.85017449019828],
    tooltip='Kawasan Ancol',
    popup='Kawasan wisata di Utara Jakarta',
    radius=1000,                                                            # radius dalam meter
    color='green'
)

ancol_area.add_to(jakarta_map)
pik_area.add_to(jakarta_map)
halim_pin.add_to(jakarta_map)
monas_pin.add_to(jakarta_map)
jakarta_map

# pilihan warna
# 'red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue'
# 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31510c7879dff7b2c7cc1b0522141a0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31510c7879dff7b2c7cc1b0522141a0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_31510c7879dff7b2c7cc1b0522141a0b = L.map(
#                 &quot;map_31510c7879dff7b2c7cc1b0522141a0b&quot;,
#                 {
#                     center: [-6.175392, 106.827153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5019114eccb977ac1ff0458378a7429b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31510c7879dff7b2c7cc1b0522141a0b);
#
#
#             var circle_e2eb000541bd0ce67fbf4ea316ba621b = L.circle(
#                 [-6.117928361275429, 106.85017449019828],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31510c7879dff7b2c7cc1b0522141a0b);
#
#
#         var popup_326810cd7f0d10365426c8f066f499d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9d158b4eb08bfcac8113cb228a15c75c = $(`&lt;div id=&quot;html_9d158b4eb08bfcac8113cb228a15c75c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kawasan wisata di Utara Jakarta&lt;/div&gt;`)[0];
#             popup_326810cd7f0d10365426c8f066f499d7.setContent(html_9d158b4eb08bfcac8113cb228a15c75c);
#
#
#         circle_e2eb000541bd0ce67fbf4ea316ba621b.bindPopup(popup_326810cd7f0d10365426c8f066f499d7)
#         ;
#
#
#
#
#             circle_e2eb000541bd0ce67fbf4ea316ba621b.bindTooltip(
#                 `&lt;div&gt;
#                      Kawasan Ancol
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_c19b031f548a4e5aa49a02317e94ee45 = L.circleMarker(
#                 [-6.1089382715126055, 106.73995330939384],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31510c7879dff7b2c7cc1b0522141a0b);
#
#
#         var popup_478d788870b011423bb68678b31f0911 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_82823abb980aa4c5259cd26d54635364 = $(`&lt;div id=&quot;html_82823abb980aa4c5259cd26d54635364&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area Rawan Bencana Banjir Rob&lt;/div&gt;`)[0];
#             popup_478d788870b011423bb68678b31f0911.setContent(html_82823abb980aa4c5259cd26d54635364);
#
#
#         circle_marker_c19b031f548a4e5aa49a02317e94ee45.bindPopup(popup_478d788870b011423bb68678b31f0911)
#         ;
#
#
#
#
#             circle_marker_c19b031f548a4e5aa49a02317e94ee45.bindTooltip(
#                 `&lt;div&gt;
#                      Pantai Indah Kapuk
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf8f0e9ed76aadc6933e8e8c0f8726bf = L.marker(
#                 [-6.265071274791165, 106.88555279590285],
#                 {}
#             ).addTo(map_31510c7879dff7b2c7cc1b0522141a0b);
#
#
#             var icon_9e6c6d82134dc24ead1c677e510bdf2a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cf8f0e9ed76aadc6933e8e8c0f8726bf.setIcon(icon_9e6c6d82134dc24ead1c677e510bdf2a);
#
#
#         var popup_7733b2799939600a156f547bb5ef01c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dadb84be2fb337101e2f8f8f819e2d3d = $(`&lt;div id=&quot;html_dadb84be2fb337101e2f8f8f819e2d3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bandar Udara sipil utama di Kota Jakarta&lt;/div&gt;`)[0];
#             popup_7733b2799939600a156f547bb5ef01c4.setContent(html_dadb84be2fb337101e2f8f8f819e2d3d);
#
#
#         marker_cf8f0e9ed76aadc6933e8e8c0f8726bf.bindPopup(popup_7733b2799939600a156f547bb5ef01c4)
#         ;

# %% [markdown]
# Selanjutnya kita akan coba membuat marker dengan data yang lain. Mari unduh dan impor data insiden departemen kepolisian menggunakan metode *pandas* `read_csv()`. Unduh dataset dan simpan dalam dataframe *pandas*:

# %%
df_incidents = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Police_Department_Incidents_-_Previous_Year__2016_.csv')
df_incidents.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
# 2   KEITH ST / SHAFTER AV -122.388856  37.729981
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000

# %% [markdown]
# Setiap baris terdiri dari 13 fitur:
# > 1. **IncidntNum**: Incident Number
# > 2. **Category**: Category of crime or incident
# > 3. **Descript**: Description of the crime or incident
# > 4. **DayOfWeek**: The day of week on which the incident occurred
# > 5. **Date**: The Date on which the incident occurred
# > 6. **Time**: The time of day on which the incident occurred
# > 7. **PdDistrict**: The police department district
# > 8. **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
# > 9. **Address**: The closest address to where the incident took place
# > 10. **X**: The longitude value of the crime location
# > 11. **Y**: The latitude value of the crime location
# > 12. **Location**: A tuple of the latitude and the longitude values
# > 13. **PdId**: The police department ID

# %% [markdown]
# Mari kita cari tahu berapa banyak entri yang ada di dataset kita.

# %%
df_incidents.shape
# Out:
# (150500, 13)

# %% [markdown]
# Jadi datframenya terdiri dari 150.500 kejahatan yang terjadi pada tahun 2016. Untuk mengurangi biaya komputasi, mari kita kerjakan 100 insiden pertama dalam kumpulan data ini.

# %%
df_incidents = df_incidents.head(100)

# %% [markdown]
# Mari kita cek bahwa dataframe kita sekarang hanya terdiri dari 100 kejahatan.

# %%
df_incidents.shape
# Out:
# (100, 13)

# %% [markdown]
# Sekarang setelah kita sedikit mengurangi datanya, mari kita visualisasikan di mana saja kejahatan ini terjadi di kota San Francisco. Kami akan menggunakan style default dan inisialisasi tingkat zoom ke 12.

# %%
# latitude dan longitude San Francisco 
latitude = 37.77
longitude = -122.42

# %%
sanfran_map = folium.Map([latitude, longitude], zoom_start=12)
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_784fb160f3ec35b66fa0caea2887f12c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_784fb160f3ec35b66fa0caea2887f12c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_784fb160f3ec35b66fa0caea2887f12c = L.map(
#                 &quot;map_784fb160f3ec35b66fa0caea2887f12c&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6da1c6ce325d2a5c3c608b8d9c3b42e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_784fb160f3ec35b66fa0caea2887f12c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Sekarang mari kita letakkan lokasi kejahatan pada peta. Cara melakukannya di **Folium** adalah dengan membuat *grup fitur* dengan fitur dan gayanya sendiri lalu menambahkannya ke `sanfran_map`.

# %%
# Membuat Grup Fitur bernama incidents
incidents = folium.map.FeatureGroup()

for lat, long in list(zip(df_incidents['Y'], df_incidents['X'])):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # fill=True berarti markernya akan diisi warna
            fill_color='blue',      # warna isi biru
            fill_opacity=0.6        # opacity 60%
        )
    )

# menambahkan Group Incident ke dalam peta sanfran_map
sanfran_map.add_child(incidents)

# tampilkan peta
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_784fb160f3ec35b66fa0caea2887f12c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_784fb160f3ec35b66fa0caea2887f12c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_784fb160f3ec35b66fa0caea2887f12c = L.map(
#                 &quot;map_784fb160f3ec35b66fa0caea2887f12c&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6da1c6ce325d2a5c3c608b8d9c3b42e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_784fb160f3ec35b66fa0caea2887f12c);
#
#
#             var feature_group_dc742a4cb244e28165cce65fe6de8bc6 = L.featureGroup(
#                 {}
#             ).addTo(map_784fb160f3ec35b66fa0caea2887f12c);
#
#
#             var circle_marker_9a208b9c45244c325c9ec2bb3ee10da5 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_bf7c6c1a75e3e8bc71f301c738e559ad = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_d8eddb0be015d6b989829d332545ad9f = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_d0ebfc8201073a8905916aa11f16c2cf = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_12ebbfa53062deb9f7aa47ba2641c965 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_e505d45b531995ca1a7ad0537541e73a = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# Kita juga dapat menambahkan beberapa teks pop-up yang akan ditampilkan saat kita mengarahkan kursor ke penanda. Mari kita buat setiap penanda menampilkan kategori kejahatan ketika diarahkan.

# %%
# Membuat Grup Fitur bernama incidents
incidents = folium.map.FeatureGroup()

for lat, long in list(zip(df_incidents['Y'], df_incidents['X'])):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # fill=True berarti markernya akan diisi warna
            fill_color='blue',      # warna isi biru
            fill_opacity=0.6        # opacity 60%
        )
    )

# menambahkan pop up berisi jenis kejahatan
for lat, long, label in list(zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category'])):
    folium.Marker(
        [lat, long],
        popup=label
    ).add_to(sanfran_map)

# menambahkan Group Incident ke dalam peta sanfran_map
sanfran_map.add_child(incidents)

# tampilkan peta
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_784fb160f3ec35b66fa0caea2887f12c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_784fb160f3ec35b66fa0caea2887f12c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_784fb160f3ec35b66fa0caea2887f12c = L.map(
#                 &quot;map_784fb160f3ec35b66fa0caea2887f12c&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6da1c6ce325d2a5c3c608b8d9c3b42e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_784fb160f3ec35b66fa0caea2887f12c);
#
#
#             var feature_group_dc742a4cb244e28165cce65fe6de8bc6 = L.featureGroup(
#                 {}
#             ).addTo(map_784fb160f3ec35b66fa0caea2887f12c);
#
#
#             var circle_marker_9a208b9c45244c325c9ec2bb3ee10da5 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_bf7c6c1a75e3e8bc71f301c738e559ad = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_d8eddb0be015d6b989829d332545ad9f = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_d0ebfc8201073a8905916aa11f16c2cf = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_12ebbfa53062deb9f7aa47ba2641c965 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_dc742a4cb244e28165cce65fe6de8bc6);
#
#
#             var circle_marker_e505d45b531995ca1a7ad0537541e73a = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# Sekarang kita dapat mengetahui kategori kejahatan yang terjadi di setiap penanda.
#
# Jika kita merasa peta terlalu padat dengan semua penanda ini, ada dua solusi untuk masalah ini. Solusi yang lebih sederhana adalah menghapus penanda lokasi ini dan hanya menambahkan teks ke penanda lingkaran itu sendiri sebagai berikut:

# %%
sanfran_map = folium.Map([37.77, -122.42], zoom_start=12)

# Membuat Grup Fitur bernama incidents
incidents = folium.map.FeatureGroup()

for lat, long, label in list(zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category'])):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # fill=True berarti markernya akan diisi warna
            fill_color='blue',      # warna isi biru
            fill_opacity=0.6,       # opacity 60%
            popup=label
        )
    )

# menambahkan Group Incident ke dalam peta sanfran_map
sanfran_map.add_child(incidents)

# tampilkan peta
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58a123fbf3b495f79939256aaef1fdc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58a123fbf3b495f79939256aaef1fdc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_58a123fbf3b495f79939256aaef1fdc4 = L.map(
#                 &quot;map_58a123fbf3b495f79939256aaef1fdc4&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_924fb08b5b57452e8179ffe89b4e8b3e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58a123fbf3b495f79939256aaef1fdc4);
#
#
#             var feature_group_ab92c21fa8bd71a4cdb7e2dd4c4e3309 = L.featureGroup(
#                 {}
#             ).addTo(map_58a123fbf3b495f79939256aaef1fdc4);
#
#
#             var circle_marker_c7d05c8b6a78a10f0367ec50ff21ec07 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ab92c21fa8bd71a4cdb7e2dd4c4e3309);
#
#
#         var popup_f56a1db2b165a23a7c444d3ed80a0364 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f1b0ab0705e0f266b806ef432df03bb = $(`&lt;div id=&quot;html_6f1b0ab0705e0f266b806ef432df03bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_f56a1db2b165a23a7c444d3ed80a0364.setContent(html_6f1b0ab0705e0f266b806ef432df03bb);
#
#
#         circle_marker_c7d05c8b6a78a10f0367ec50ff21ec07.bindPopup(popup_f56a1db2b165a23a7c444d3ed80a0364)
#         ;
#
#
#
#
#             var circle_marker_82ec7e65c980dd03944feb5ba1f2dcc0 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ab92c21fa8bd71a4cdb7e2dd4c4e3309);
#
#
#         var popup_88e19a23cd91cecadfd916412c580653 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_def4698e20c49ef15a38f624251f15d3 = $(`&lt;div id=&quot;html_def4698e20c49ef15a38f624251f15d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_88e19a23cd91cecadfd916412c580653.setContent(html_def4698e20c49ef15a38f624251f15d3);
#
#
#         circle_marker_82ec7e65c980dd03944feb5ba1f2dcc0.bindPopup(popup_88e19a23cd91cecadfd916412c580653)
#         ;
#
#
#
#
#             var circle_marker_84eee124de5968532980cd6356c9d970 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ab92c21fa8bd71a4cdb7e2dd4c4e3309);
#
#
#         var popup_5c599b3b6edafa0c06aa38383db5bbdc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_84e4e0ede64bda73310752981e89f6f1 = $(`&lt;div id=&quot;html_84e4e0ede64bda73310752981e89f6f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_5c599b3b6edafa0c06aa38383db5bbdc.setContent(html_84e4e0ede64bda73310752981e89f6f1);
#
#
#         circle_marker_84eee124de5968532980cd6356c9d970.bindPopup(popup_5c599b3b6edafa0c06aa38383db5bbdc)
#         ;
#
#
#
#
#             var circle_marker_5864cf2fe762ce1e827b90b9a6db16a3 = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&

# %% [markdown]
# Solusi yang tepat lainnya adalah mengelompokkan penanda ke dalam klaster yang berbeda. Setiap klaster kemudian direpresentasikan oleh jumlah kejahatan di setiap lingkungan. Klaster ini dapat dianggap sebagai kantong-kantong San Francisco yang kemudian dapat kita analisis secara terpisah.
#
# Untuk menerapkannya, kita memulai dengan menginisialisasi sebuah objek `MarkerCluster` dan menambahkan semua titik data dalam dataframe ke objek ini.

# %%
from folium import plugins

# membuat peta
sanfran_map = folium.Map([37.77, -122.42], zoom_start=12)

# menginisiasi MarkerCluster
incidents = plugins.MarkerCluster().add_to(sanfran_map)

# menambahkan marker ke dalam MarkerCluster
for lat, long, label in list(zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category'])):
    folium.Marker(
        [lat, long],
        popup=label,
        icon=None
    ).add_to(incidents)

# tampilkan
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e520bd8717942fff40433642f28cd4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e520bd8717942fff40433642f28cd4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1e520bd8717942fff40433642f28cd4d = L.map(
#                 &quot;map_1e520bd8717942fff40433642f28cd4d&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e9b85d01d0db401803874515dfc10ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1e520bd8717942fff40433642f28cd4d);
#
#
#             var marker_cluster_fc274741500694cc7603d12ee841f573 = L.markerClusterGroup(
#                 {}
#             );
#             map_1e520bd8717942fff40433642f28cd4d.addLayer(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#             var marker_840855603fdb85286e6d4f3cc4663ed3 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#         var popup_f40e3bd7988f9b995ac84d2c9eeff376 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_003e12524714b57fcf6b559c5898b24d = $(`&lt;div id=&quot;html_003e12524714b57fcf6b559c5898b24d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_f40e3bd7988f9b995ac84d2c9eeff376.setContent(html_003e12524714b57fcf6b559c5898b24d);
#
#
#         marker_840855603fdb85286e6d4f3cc4663ed3.bindPopup(popup_f40e3bd7988f9b995ac84d2c9eeff376)
#         ;
#
#
#
#
#             var marker_bbe27c32d94f688b88c98e6febe698ca = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#         var popup_798a05d451f8d2f02bd341b1a6fe7673 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_af16b6f8f5f78f6c87d48584e987ff61 = $(`&lt;div id=&quot;html_af16b6f8f5f78f6c87d48584e987ff61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_798a05d451f8d2f02bd341b1a6fe7673.setContent(html_af16b6f8f5f78f6c87d48584e987ff61);
#
#
#         marker_bbe27c32d94f688b88c98e6febe698ca.bindPopup(popup_798a05d451f8d2f02bd341b1a6fe7673)
#         ;
#
#
#
#
#             var marker_39292fa2bf56984782415882ca41c1df = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#         var popup_fc869ada12120dcc076c6311a97b0f8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8bc276ef9ab5550fc65d71c135a7c485 = $(`&lt;div id=&quot;html_8bc276ef9ab5550fc65d71c135a7c485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_fc869ada12120dcc076c6311a97b0f8e.setContent(html_8bc276ef9ab5550fc65d71c135a7c485);
#
#
#         marker_39292fa2bf56984782415882ca41c1df.bindPopup(popup_fc869ada12120dcc076c6311a97b0f8e)
#         ;
#
#
#
#
#             var marker_baf59d3c81058a9081baad2aae891de0 = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#         var popup_23d97cf47eb8a6e63dd6b1e5eb3028b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_01fe646e641bb1e0a1abdf4006fb030f = $(`&lt;div id=&quot;html_01fe646e641bb1e0a1abdf4006fb030f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_23d97cf47eb8a6e63dd6b1e5eb3028b1.setContent(html_01fe646e641bb1e0a1abdf4006fb030f);
#
#
#         marker_baf59d3c81058a9081baad2aae891de0.bindPopup(popup_23d97cf47eb8a6e63dd6b1e5eb3028b1)
#         ;
#
#
#
#
#             var marker_5f91b3926c641801bc80c429b7d99eeb = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(marker_cluster_fc274741500694cc7603d12ee841f573);
#
#
#         var popup_2e15ba1ede8cf0127debf5bf63f2c23d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a6a87cb957809f3f05b0884be3939d25 = $(`&lt;div id=&quot;

# %% [markdown]
# Perhatikan bagaimana saat Anda memperkecil tampilan peta sepenuhnya, semua penanda digabungkan ke dalam satu klaster, *klaster global*, dengan 100 penanda atau kejahatan, yang merupakan total jumlah kejahatan dalam dataframe kami. Begitu Anda mulai memperbesar, *klaster global* akan mulai terpecah menjadi klaster yang lebih kecil. Memperbesar hingga sepenuhnya akan menghasilkan penanda individu.

# %% [markdown]
# ## **4. Choropleth Maps**
#
#
# Peta `Choropleth` adalah peta tematis di mana area-area diarsir atau dipola secara proporsional dengan pengukuran variabel statistik yang ditampilkan pada peta, seperti kepadatan penduduk atau pendapatan per kapita. Peta `choropleth` menyediakan cara yang mudah untuk memvisualisasikan bagaimana pengukuran bervariasi di seluruh area geografis, atau menunjukkan tingkat variabilitas dalam suatu wilayah. Di bawah ini adalah peta `Choropleth` dari Amerika Serikat yang menggambarkan populasi per mil persegi per negara bagian.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%205/images/2000_census_population_density_map_by_state.png" width="600">

# %% [markdown]
# Sekarang kita akan membuat `Choropleth` yang menggambarkan perpindahan penduduk di kota Jakarta.

# %% [markdown]
# Pertama kita baca terlebih dahulu file `pendatang_DKI_Maret_2020.csv` ke dalam *pandas* dataframe.

# %%
df = pd.read_csv('pendatang_DKI_Maret_2020.csv')

# %%
df.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     0.0
# 1       PULAU KELAPA      Laki-Laki     2.0
# 2      PULAU HARAPAN      Laki-Laki     1.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     3.0
# 4       PULAU TIDUNG      Laki-Laki     3.0

# %% [markdown]
# Selanjutnya kita perlu menampilkan jumlah pendatang berdasarkan kelurahan.

# %%
df = df.groupby('kelurahan')[['jumlah']].sum().reset_index()
df.head()
# Out:
#      kelurahan  jumlah
# 0        ANCOL    17.0
# 1        ANGKE    22.0
# 2  BALEKAMBANG    30.0
# 3  BALI MESTER     4.0
# 4   BAMBU APUS    26.0

# %%
df[df['jumlah']==df['jumlah'].min()]
# Out:
#           kelurahan  jumlah
# 97   KARET SEMANGGI     0.0
# 214      RAWA BARAT     0.0

# %% [markdown]
# Dalam rangka membuat peta `Choropleth`, kita membutuhkan file GeoJSON yang mendefinisikan area/batas dari suatu kota, provinsi, atau negara yang menarik perhatian kita. Dalam kasus ini, karena kita berusaha membuat peta jakarta, kita membutuhkan GeoJSON yang membatasi seluruh kelurahan di kota Jakarta. Demi kenyamanan, kita sudah menyediakan file `jakarta_by_kelurahan_geo.geojson`. Mari kita namai jakarta_geojson

# %%
jakarta_geojson = r'jakarta_by_kelurahan_geo.geojson'

# %% [markdown]
# Untuk mengetahui apa yang terkandung di dalamnya kita bisa menggunakan metode `read_json`.

# %%
pd.read_json(jakarta_geojson).loc[0, 'features']['properties']['name']
# Out:
# 'ANGKE'

# %% [markdown]
# Dan sekarang untuk membuat peta `Choropleth`, kita akan menggunakan metode *choropleth* dengan parameter utama sebagai berikut:
#
# 1. `geo_data`, yaitu file GeoJSON.
# 2. `data`, yaitu dataframe yang berisi data.
# 3. `columns`, yang mewakili kolom-kolom dalam dataframe yang akan digunakan untuk membuat peta `Choropleth`.
# 4. `key_on`, yaitu kunci atau variabel pada file GeoJSON yang berisi nama variabel yang diinginkan. Untuk menentukannya, kita perlu membuka file GeoJSON menggunakan editor teks apa pun dan mencatat nama kunci atau variabel yang berisi nama kelurahan, karena kelurahan adalah variabel yang kita minati. Dalam hal ini, **name** adalah kunci dalam file GeoJSON yang berisi nama kelurahan. Perhatikan bahwa kunci ini case sensitive, jadi kita harus meneruskannya persis seperti yang ada di file GeoJSON.

# %%
df
# Out:
#              kelurahan  jumlah
# 0                ANCOL    17.0
# 1                ANGKE    22.0
# 2          BALEKAMBANG    30.0
# 3          BALI MESTER     4.0
# 4           BAMBU APUS    26.0
# ..                 ...     ...
# 262  UTAN KAYU SELATAN    30.0
# 263    UTAN KAYU UTARA    25.0
# 264       UTAN PANJANG    13.0
# 265            WARAKAS    22.0
# 266      WIJAYA KUSUMA    31.0
#
# [267 rows x 2 columns]

# %%
# membuat peta jakarta
jakarta_map = folium.Map(
    [-6.2, 106.816666],
    zoom_start=11
)

chor_kelurahan = folium.Choropleth(
    geo_data=jakarta_geojson,               # file geojson
    data=df,                                # dataframe pandas
    columns=['kelurahan', 'jumlah'],        # kolom dataframe yang dipakai
    key_on='feature.properties.name'        # indexing nama kelurahan pada file json (di 'name')
)

chor_kelurahan.add_to(jakarta_map)
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7063176a79abaa904b8981c20fd2d43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7063176a79abaa904b8981c20fd2d43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d7063176a79abaa904b8981c20fd2d43 = L.map(
#                 &quot;map_d7063176a79abaa904b8981c20fd2d43&quot;,
#                 {
#                     center: [-6.2, 106.816666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd1c5a1f7f9d9097cae64cdc6b8a232f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d7063176a79abaa904b8981c20fd2d43);
#
#
#             var choropleth_dd462eefa147cc110332dbcc138a6364 = L.featureGroup(
#                 {}
#             ).addTo(map_d7063176a79abaa904b8981c20fd2d43);
#
#
#         function geo_json_49b955e88c3e79ad0d34947bf62e2979_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;PASEBAN&quot;: case &quot;DUREN SAWIT&quot;: case &quot;KEBON BAWANG&quot;: case &quot;BATU AMPAR&quot;: case &quot;CEMPAKA BARU&quot;: case &quot;BIDARA CINA&quot;: case &quot;BAMBU APUS&quot;: case &quot;BARU&quot;: case &quot;BINTARO&quot;: case &quot;CAWANG&quot;: case &quot;CEMPAKA PUTIH BARAT&quot;: case &quot;CIGANJUR&quot;: case &quot;CIJANTUNG&quot;: case &quot;CILANDAK BARAT&quot;: case &quot;CILANDAK TIMUR&quot;: case &quot;DUREN TIGA&quot;: case &quot;CILANGKAP&quot;: case &quot;CILILITAN&quot;: case &quot;CILINCING&quot;: case &quot;CIPETE UTARA&quot;: case &quot;CIPINANG&quot;: case &quot;CIPINANG BESAR SELATAN&quot;: case &quot;CIPINANG BESAR UTARA&quot;: case &quot;DURI KEPA&quot;: case &quot;GANDARIA UTARA&quot;: case &quot;GEDONG&quot;: case &quot;GROGOL UTARA&quot;: case &quot;GUNUNG SAHARI SELATAN&quot;: case &quot;JAGAKARSA&quot;: case &quot;JELAMBAR BARU&quot;: case &quot;JEMBATAN BESI&quot;: case &quot;JOHAR BARU&quot;: case &quot;KALI ANYAR&quot;: case &quot;KALIBATA&quot;: case &quot;KALISARI&quot;: case &quot;KAMAL MUARA&quot;: case &quot;KAMPUNG MELAYU&quot;: case &quot;KEDAUNG KALI ANGKE&quot;: case &quot;KAYU PUTIH&quot;: case &quot;KEBAYORAN LAMA SELATAN&quot;: case &quot;KEBAYORAN LAMA UTARA&quot;: case &quot;KEBON PALA&quot;: case &quot;KEDOYA UTARA&quot;: case &quot;KELAPA GADING BARAT&quot;: case &quot;LAGOA&quot;: case &quot;KEMBANGAN UTARA&quot;: case &quot;KOJA&quot;: case &quot;LUBANG BUAYA&quot;: case &quot;MAKASAR&quot;: case &quot;SERDANG&quot;: case &quot;MANGGA DUA SELATAN&quot;: case &quot;MARUNDA&quot;: case &quot;MERUYA SELATAN&quot;: case &quot;MERUYA UTARA&quot;: case &quot;PAPANGGO&quot;: case &quot;PEGANGSAAN DUA&quot;: case &quot;PEJATEN TIMUR&quot;: case &quot;PEKAYON&quot;: case &quot;PESANGGRAHAN&quot;: case &quot;PETUKANGAN SELATAN&quot;: case &quot;PISANGAN BARU&quot;: case &quot;PISANGAN TIMUR&quot;: case &quot;RAWAJATI&quot;: case &quot;PLUIT&quot;: case &quot;PONDOK KOPI&quot;: case &quot;PONDOK PINANG&quot;: case &quot;SUSUKAN&quot;: case &quot;RAWA BADAK SELATAN&quot;: case &quot;RAWA BADAK UTARA&quot;: case &quot;RAWAMANGUN&quot;: case &quot;ROROTAN&quot;: case &quot;SEMPER TIMUR&quot;: case &quot;TANAH TINGGI&quot;: case &quot;SRENGSENG&quot;: case &quot;SUKABUMI SELATAN&quot;: case &quot;SUKABUMI UTARA&quot;: case &quot;SUNGAI BAMBU&quot;: case &quot;SUNTER JAYA&quot;: case &quot;TANJUNG PRIOK&quot;: case &quot;TUGU UTARA&quot;: case &quot;UJUNG MENTENG&quot;: case &quot;ULUJAMI&quot;: case &quot;UTAN KAYU SELATAN&quot;: case &quot;UTAN KAYU UTARA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;SETIABUDI&quot;: case &quot;BALE KAMBANG&quot;: case &quot;JATI PULO&quot;: case &quot;JATIPADANG&quot;: case &quot;HALIM PERDANA KUSUMA&quot;: case &quot;KAMPUNG TENGAH&quot;: case &quot;KRAMAT JATI&quot;: case &quot;PAL MERIAM&quot;: case &quot;PINANG RANTI&quot;: case &quot;PONDOK RANGON&quot;: case &quot;PULOGADUNG&quot;: case &quot;TMII&quot;: case &quot;WIJAYA KESUMA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CAKUNG BARAT&quot;: case &quot;CAKUNG TIMUR&quot;: case &quot;CENGKARENG BARAT&quot;: case &quot;CIBUBUR&quot;: case &quot;CIRACAS&quot;: case &quot;JOGLO&quot;: case &quot;KALIBARU&quot;: case &quot;KAMAL&quot;: case &quot;KEBON JERUK&quot;: case &quot;KEBON KOSONG&quot;: case &quot;KEBON MELATI&quot;: case &quot;KLENDER&quot;: case &quot;KRAMAT&quot;: case &quot;LENTENG AGUNG&quot;: case &quot;PADEMANGAN BARAT&quot;:

# %% [markdown]
# Sesuai dengan legenda pada peta `Choroplet`, semakin gelap warna suatu kelurahan dan semakin mendekati warna biru tua, semakin tinggi jumlah perpindahan penduduknya. Oleh karena itu, perpindahan penduduk terjadi di sekitar perbatasan kota Jakarta.
#
# Perhatikan bahwa masih terdapat data yang tidak muncul di dalam peta, hal ini bisa terjadi karena nama kelurahan pada file geojson dan pada dataframe berbeda. Sehingga kita perlu sesuaikan nama-namanya terlebih dahulu.

# %%
df[df['kelurahan'].str.contains('TMII')]
# Out:
# Empty DataFrame
# Columns: [kelurahan, jumlah]
# Index: []

# %%
df['kelurahan'] = df['kelurahan'].str.replace('WIJAYA KUSUMA', 'WIJAYA KESUMA')         
df['kelurahan'] = df['kelurahan'].str.replace('JATIPULO', 'JATI PULO')
df['kelurahan'] = df['kelurahan'].str.replace('SETIA BUDI', 'SETIABUDI')
df['kelurahan'] = df['kelurahan'].str.replace('PALMERIAM', 'PAL MERIAM')
df['kelurahan'] = df['kelurahan'].str.replace('PULO GADUNG', 'PULOGADUNG')
df['kelurahan'] = df['kelurahan'].str.replace('HALIM PERDANA KUSUMAH', 'HALIM PERDANA KUSUMA')
df['kelurahan'] = df['kelurahan'].str.replace('PINANGRANTI', 'PINANG RANTI')
df['kelurahan'] = df['kelurahan'].str.replace('KRAMATJATI', 'KRAMAT JATI')
df['kelurahan'] = df['kelurahan'].str.replace('TENGAH', 'KAMPUNG TENGAH')
df['kelurahan'] = df['kelurahan'].str.replace('BALEKAMBANG', 'BALE KAMBANG')
df['kelurahan'] = df['kelurahan'].str.replace('JATI PADANG', 'JATIPADANG')
df['kelurahan'] = df['kelurahan'].str.replace('PONDOK RANGGON', 'PONDOK RANGON')

# %%
df.loc[267, 'kelurahan']='TMII'
df.loc[267, 'jumlah']= 0
df
# Out:
#            kelurahan  jumlah
# 0              ANCOL    17.0
# 1              ANGKE    22.0
# 2       BALE KAMBANG    30.0
# 3        BALI MESTER     4.0
# 4         BAMBU APUS    26.0
# ..               ...     ...
# 263  UTAN KAYU UTARA    25.0
# 264     UTAN PANJANG    13.0
# 265          WARAKAS    22.0
# 266    WIJAYA KESUMA    31.0
# 267             TMII     0.0
#
# [268 rows x 2 columns]

# %% [markdown]
# Setelah kita perbaiki datanya, kita akan coba tampilkan kembali sambil mengubah warna dan legenda dari peta tersebut.

# %%
rentang_jumlah = df['jumlah'].quantile([0, 0.25, 0.5, 0.75, 1])

# %%
# membuat peta jakarta
jakarta_map = folium.Map(
    [-6.2, 106.816666],
    zoom_start=11
)

chor_kelurahan = folium.Choropleth(
    geo_data=jakarta_geojson,               # file geojson
    data=df,                                # dataframe pandas
    columns=['kelurahan', 'jumlah'],        # kolom dataframe yang dipakai
    key_on='feature.properties.name',       # indexing nama kelurahan pada file json (di 'name')
    fill_color='YlOrRd',                    # mengubah warna
    legend_name='Jumlah Pendatang',         # menambahkan nama dari legenda
    fill_opacity=0.5,                       # mengatur transparansi
    bins=rentang_jumlah
)

chor_kelurahan.add_to(jakarta_map)
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5eca89d9962e76d6baea4be9047adbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5eca89d9962e76d6baea4be9047adbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d5eca89d9962e76d6baea4be9047adbb = L.map(
#                 &quot;map_d5eca89d9962e76d6baea4be9047adbb&quot;,
#                 {
#                     center: [-6.2, 106.816666],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27d7a78bcd3d56fe56f899cf90d40bac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5eca89d9962e76d6baea4be9047adbb);
#
#
#             var choropleth_6750ca34b8bf7e926ea72c7c0266d9c7 = L.featureGroup(
#                 {}
#             ).addTo(map_d5eca89d9962e76d6baea4be9047adbb);
#
#
#         function geo_json_8ae9a8c891290662fd3a0359b24edbd0_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;ANGKE&quot;: case &quot;KRENDANG&quot;: case &quot;PETOJO UTARA&quot;: case &quot;ANCOL&quot;: case &quot;BUKIT DURI&quot;: case &quot;CEGER&quot;: case &quot;CEMPAKA PUTIH TIMUR&quot;: case &quot;GALUR&quot;: case &quot;MANGGARAI SELATAN&quot;: case &quot;CIPAYUNG&quot;: case &quot;CIPEDAK&quot;: case &quot;CIPETE SELATAN&quot;: case &quot;CIPINANG CEMPEDAK&quot;: case &quot;CIPINANG MUARA&quot;: case &quot;CIPULIR&quot;: case &quot;DUKUH&quot;: case &quot;DURI PULO&quot;: case &quot;DURI UTARA&quot;: case &quot;GANDARIA SELATAN&quot;: case &quot;GROGOL&quot;: case &quot;GROGOL SELATAN&quot;: case &quot;HARAPAN MULIA&quot;: case &quot;JATI&quot;: case &quot;JATINEGARA KAUM&quot;: case &quot;JELAMBAR&quot;: case &quot;JEMBATAN LIMA&quot;: case &quot;KAPUK MUARA&quot;: case &quot;KARANG ANYAR&quot;: case &quot;KARET TENGSIN&quot;: case &quot;KAYU MANIS&quot;: case &quot;KEBAGUSAN&quot;: case &quot;KEBON KACANG&quot;: case &quot;KEBON KELAPA&quot;: case &quot;KEBON SIRIH&quot;: case &quot;KWITANG&quot;: case &quot;KEDOYA SELATAN&quot;: case &quot;KELAPA DUA&quot;: case &quot;KELAPA GADING TIMUR&quot;: case &quot;KEMAYORAN&quot;: case &quot;KEMBANGAN SELATAN&quot;: case &quot;KENARI&quot;: case &quot;KOTA BAMBU UTARA&quot;: case &quot;KRAMAT JATI&quot;: case &quot;KRAMAT PELA&quot;: case &quot;LEBAK BULUS&quot;: case &quot;MALAKA JAYA&quot;: case &quot;MALAKA SARI&quot;: case &quot;MAPHAR&quot;: case &quot;MENTENG&quot;: case &quot;MUNJUL&quot;: case &quot;PASAR MANGGIS&quot;: case &quot;PASAR MINGGU&quot;: case &quot;PEGANGSAAN&quot;: case &quot;PEJATEN BARAT&quot;: case &quot;PEKOJAN&quot;: case &quot;PELA MAMPANG&quot;: case &quot;PETAMBURAN&quot;: case &quot;PETOJO SELATAN&quot;: case &quot;RAWA BUNGA&quot;: case &quot;RAWA TERATE&quot;: case &quot;RAWASARI&quot;: case &quot;SETU&quot;: case &quot;SUMUR BATU&quot;: case &quot;TANJUNG BARAT&quot;: case &quot;TEGAL PARANG&quot;: case &quot;UTAN PANJANG&quot;: case &quot;WARAKAS&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fecc5c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;PASEBAN&quot;: case &quot;DUREN SAWIT&quot;: case &quot;BALE KAMBANG&quot;: case &quot;BAMBU APUS&quot;: case &quot;BARU&quot;: case &quot;BINTARO&quot;: case &quot;CAWANG&quot;: case &quot;CEMPAKA PUTIH BARAT&quot;: case &quot;CILANDAK TIMUR&quot;: case &quot;DUREN TIGA&quot;: case &quot;CILANGKAP&quot;: case &quot;JATI PULO&quot;: case &quot;CILINCING&quot;: case &quot;CIPETE UTARA&quot;: case &quot;CIPINANG&quot;: case &quot;CIPINANG BESAR SELATAN&quot;: case &quot;CIPINANG BESAR UTARA&quot;: case &quot;DURI KEPA&quot;: case &quot;JATIPADANG&quot;: case &quot;GANDARIA UTARA&quot;: case &quot;GEDONG&quot;: case &quot;GROGOL UTARA&quot;: case &quot;GUNUNG SAHARI SELATAN&quot;: case &quot;JELAMBAR BARU&quot;: case &quot;JEMBATAN BESI&quot;: case &quot;JOHAR BARU&quot;: case &quot;KALI ANYAR&quot;: case &quot;KALISARI&quot;: case &quot;KAMAL MUARA&quot;: case &quot;KAMPUNG MELAYU&quot;: case &quot;KEDAUNG KALI ANGKE&quot;: case &quot;KAYU PUTIH&quot;: case &quot;KEBAYORAN LAMA SELATAN&quot;: case &quot;KEBAYORAN LAMA UTARA&quot;: case &quot;KEBON PALA&quot;: case &quot;KEDOYA UTARA&quot;: case &quot;LAGOA&quot;: case &quot;KOJA&quot;: case &quot;MAKASAR&quot;: case &quot;SERDANG&quot;: case &quot;MANGGA DUA SELATAN&quot;: case &quot;MARUNDA&quot;: case &quot;PALMERAH&quot;: case &quot;PAPANGGO&quot;: case &quot;PEJATEN TIMUR&quot;: case &quot;PINANG RANTI&quot;: case &quot;PISANGAN BARU&quot;: case &quot;PISANGAN TIMUR&quot;: case &quot;PONDOK KOPI&quot;: case &quot;PONDOK PINANG&quot;: case &quot;PONDOK RANGON&quot;: case &quot;RAMBUTAN&quot;: case &quot;RAWA BADAK UTARA&quot;: case &quo
